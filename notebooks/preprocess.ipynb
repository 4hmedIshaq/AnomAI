# %%
import sys, os
sys.path.append("../src")   # so you can import your scripts

# %%
from load_data import load_logs
from preprocess import clean_logs

df = load_logs()
df_clean = clean_logs(df)
df_clean
# Out:
# Loading logs from:  c:\Visual Studio folder\AnomAI\src\..\data\siem_ueba_log_git.csv
# Rows: 94999
#       AGENT_NAME                                            Content  \
# 0  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 1  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 2  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 3   UBUNTU_AGENT  Nisir_Ml_Agent[1045]:                         ...
# 4   UBUNTU_AGENT  logstash[323986]: Sending Logstash logs to /va...
#
#          src_ip        dst_ip              entity_id     City  Country  \
# 0  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 1  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 2  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 3   172.20.0.42   172.20.0.42     ubuntu@172.20.0.42  Unknown  Unknown
# 4   172.20.0.39   172.20.0.39     ubuntu@172.20.0.39  Unknown  Unknown
#
#               date  day  hour  minute  second
# 0  4/24/2025 22:14    3    22      14      26
# 1   4/25/2025 6:53    4     6      53      30
# 2   4/25/2025 3:02    4     3       2       0
# 3  12/18/2024 7:32    2     7      32      20
# 4   5/15/2025 7:03    3     7       3      19
# c:\Visual Studio folder\AnomAI\notebooks\../src\preprocess.py:13: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df2.loc[:, "timestamp"] = pd.to_datetime(df2["date"], errors="coerce", infer_datetime_format=True)
#           AGENT_NAME                                            Content  \
# 0      WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 1      WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 2      WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 3       UBUNTU_AGENT  Nisir_Ml_Agent[1045]:                         ...
# 4       UBUNTU_AGENT  logstash[323986]: Sending Logstash logs to /va...
# ...              ...                                                ...
# 94989   UBUNTU_AGENT  opensearch-dashboards[70589]: {"type":"log","@...
# 94990   UBUNTU_AGENT  logstash[4028136]:         at usr.share.logsta...
# 94991  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 94995  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
# 94998  WINDOWS_AGENT  Microsoft-Windows-Security-Auditing\tEvent ID:...
#
#              src_ip        dst_ip              entity_id     City  Country  \
# 0      172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 1      172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 2      172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 3       172.20.0.42   172.20.0.42     ubuntu@172.20.0.42  Unknown  Unknown
# 4       172.20.0.39   172.20.0.39     ubuntu@172.20.0.39  Unknown  Unknown
# ...             ...           ...                    ...      ...      ...
# 94989   172.20.0.47   172.20.0.47     debian@172.20.0.47  Unknown  Unknown
# 94990   172.20.0.39   172.20.0.39     ubuntu@172.20.0.39  Unknown  Unknown
# 94991  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 94995  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
# 94998  172.20.82.33  172.20.82.33  Lemonade@172.20.82.33  Unknown  Unknown
#
#                   date  day  hour  minute  second           timestamp
# 0      4/24/2025 22:14    3    22      14      26 2025-04-24 22:14:00
# 1       4/25/2025 6:53    4     6      53      30 2025-04-25 06:53:00
# 2       4/25/2025 3:02    4     3       2       0 2025-04-25 03:02:00
# 3      12/18/2024 7:32    2     7      32      20 2024-12-18 07:32:00
# 4       5/15/2025 7:03    3     7       3      19 2025-05-15 07:03:00
# ...                ...  ...   ...     ...     ...                 ...
# 94989  4/12/2025 10:10    5    10      10       0 2025-04-12 10:10:00
# 94990   5/14/2025 6:52    2     6      52      23 2025-05-14 06:52:00
# 94991  5/14/2025 10:05    2    10       5      42 2025-05-14 10:05:00
# 94995   4/25/2025 1:42    4     1      42      59 2025-04-25 01:42:00
# 94998  4/24/2025 22:03    3    22       3       3 2025-04-24 22:03:00
#
# [59940 rows x 13 columns]

# %%
df_clean['timestamp'].info
# Out:
# <bound method Series.info of 0       2025-04-24 22:14:00
# 1       2025-04-25 06:53:00
# 2       2025-04-25 03:02:00
# 3       2024-12-18 07:32:00
# 4       2025-05-15 07:03:00
#                 ...
# 94989   2025-04-12 10:10:00
# 94990   2025-05-14 06:52:00
# 94991   2025-05-14 10:05:00
# 94995   2025-04-25 01:42:00
# 94998   2025-04-24 22:03:00
# Name: timestamp, Length: 59940, dtype: datetime64[ns]>

# %%
df.isnull().sum()
# Out:
# AGENT_NAME    0
# Content       0
# src_ip        0
# dst_ip        0
# entity_id     0
# City          0
# Country       0
# date          0
# day           0
# hour          0
# minute        0
# second        0
# dtype: int64

# %%
len(df)
# Out:
# 94999
